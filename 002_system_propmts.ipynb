# %%
# Load environment variables from .env (expects ANTHROPIC_API_KEY)
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()
# Out:
# True

# %%
client = Anthropic

# Instantiate the client (reads ANTHROPIC_API_KEY from the environment)
# model = "claude-3-haiku-20240307"
model = "claude-haiku-4-5-20251001"

# Append a user turn to the conversation history
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

# Append an assistant turn to the conversation history
def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

# Send the full conversation history and return the assistant reply
def chat(messages, system=None):
    kwargs = dict(model=model, max_tokens=1000, messages=messages)
    if system:
        kwargs["system"] = system
    message = client.messages.create(**kwargs)
    return message.content[0].text

# %%
system = """
Write just the code when I ask for code. No explanation, no comments, just the code.
"""

# %%
messages = []
add_user_message(messages, "Write a Pyhon script that writes the first 20 prime numbers")

answer = chat(messages = messages, system = system)

answer
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 4
#       1 messages = []
#       2 add_user_message(messages, "Write a Pyhon script that writes the first 20 prime numbers")
#       3
# ----> 4 answer = chat(messages = messages, system = system)
#       5
#       6 answer
#
# Cell In[2], line 22, in chat(messages, system)
#      18 def chat(messages, system=None):
#      19     kwargs = dict(model=model, max_tokens=1000, messages=messages)
#      20     if system:
#      21         kwargs["system"] = system
# ---> 22     message = client.messages.create(**kwargs)
#      23     return message.content[0].text
#
# AttributeError: 'cached_property' object has no attribute 'create'
